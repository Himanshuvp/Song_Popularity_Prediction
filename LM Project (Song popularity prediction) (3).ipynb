# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting the dimensions of visualizations

# %%
sns.set(rc={'figure.figsize':(8,6)})

# %% [markdown]
# ### Importing Data Set

# %%
df=pd.read_csv('song data.csv')

# %%
df
# Out:
#                          id                         name  duration  energy  \
# 0    0VjIjW4GlUZAMYd2vXMi3b              Blinding Lights      3.33  0.7300
# 1    7qiZfU4dY1lWllzX7mPBI3                 Shape of You      3.90  0.6520
# 2    2XU0oxnq2qxCpomAAuJY8K                 Dance Monkey      3.49  0.5880
# 3    7qEHsqek33rTcFNT9PFqLf            Someone You Loved      3.04  0.4050
# 4    0e7ipj03S05BNilyu5bRzt                     Rockstar      3.64  0.5200
# ..                      ...                          ...       ...     ...
# 195  45w0bd4DqUyjAWzTzgiDau  Twinkle Twinkle Little Star     11.60  0.0422
# 196  5KEPRpsnM3e2AZpADhFAwR               Light the Fire     49.75  0.5920
# 197  1MkXLKDhJX3DlDM6KxD2cl                        Intro     12.40  0.4030
# 198  4ELk6NnoiinMggup9hH37x                Can't Breathe     55.26  0.7140
# 199  3Yi8skfHdggEVfEBTfRBru             Someone Like You     48.43  0.6570
#
#      key  loudness  mode  speechiness  acousticness  liveness  valence  \
# 0      1    -5.934     1       0.0598       0.00146    0.0897    0.334
# 1      1    -3.183     0       0.0802       0.58100    0.0931    0.931
# 2      6    -6.400     0       0.0924       0.69200    0.1490    0.513
# 3      1    -5.679     1       0.0319       0.75100    0.1050    0.446
# 4      5    -6.136     0       0.0712       0.12400    0.1310    0.129
# ..   ...       ...   ...          ...           ...       ...      ...
# 195   11   -17.662     0       0.1640       0.75300    0.0790    0.547
# 196    6   -11.658     0       0.0359       0.00758    0.5940    0.350
# 197    0   -16.342     1       0.0881       0.98000    0.1560    0.297
# 198    0    -4.629     1       0.0370       0.00153    0.1090    0.326
# 199    7    -4.638     0       0.0316       0.02690    0.0899    0.353
#
#        tempo  danceability  Status
# 0    171.005         0.514       1
# 1     95.977         0.825       1
# 2     98.027         0.824       1
# 3    109.891         0.501       1
# 4    159.801         0.585       1
# ..       ...           ...     ...
# 195  109.021         0.717       0
# 196  119.948         0.531       0
# 197   80.011         0.187       0
# 198  168.394         0.361       0
# 199  142.532         0.376       0
#
# [200 rows x 14 columns]

# %% [markdown]
# * Hit song = 1
# * Flop song = 0

# %% [markdown]
# ### Shuffling the data
# * For unbiasedness

# %%
df2=df.sample(frac=1)

# %%
df2
# Out:
#                          id                   name  duration  energy  key  \
# 192  4R9OIaic0WuA40tMV7ZMw3  The Itsy Bitsy Spider     11.82  0.0926   11
# 190  7gzBdhUHisyTFLvOdTiIYh          London Bridge      8.08  0.0332    2
# 30   3ee8Jmje8o58CHK66QrVC2                   Sad!      2.78  0.6130    8
# 53   0lYBSQXN6rCTvUZvg9S0lU        Let Me Love You      3.43  0.7160    8
# 9    0pqnGHJpmpxLKifKRmU6WP               Believer      3.41  0.7800   10
# ..                      ...                    ...       ...     ...  ...
# 109  1HlVLS4ee3GiYocfcg8TgB                   irie     43.83  0.2090    6
# 2    2XU0oxnq2qxCpomAAuJY8K           Dance Monkey      3.49  0.5880    6
# 47   7fBv7CLKzipRk6EC6TWHOB              The Hills      4.04  0.5640    0
# 132  1Q9oighVictEedPJRcY2Ii         How Many Whips     10.18  0.5900    5
# 168  3tjfT7tho5CoHchikYOaa0     Summer Burn (Live)     36.38  0.3830    4
#
#      loudness  mode  speechiness  acousticness  liveness  valence    tempo  \
# 192   -17.108     0       0.1610        0.9760    0.1620    0.523   69.180
# 190   -20.896     1       0.1190        0.9910    0.3820    0.884  108.641
# 30     -4.880     1       0.1450        0.2580    0.1230    0.473   75.023
# 53     -5.371     1       0.0349        0.0863    0.1350    0.163   99.988
# 9      -4.374     0       0.1280        0.0622    0.0810    0.666  124.949
# ..        ...   ...          ...           ...       ...      ...      ...
# 109   -14.410     1       0.6200        0.3670    0.0632    0.298   89.102
# 2      -6.400     0       0.0924        0.6920    0.1490    0.513   98.027
# 47     -7.063     0       0.0515        0.0671    0.1350    0.137  113.003
# 132    -6.843     1       0.0607        0.1480    0.5170    0.382  134.752
# 168    -9.616     1       0.0284        0.8370    0.2060    0.288  128.123
#
#      danceability  Status
# 192         0.695       0
# 190         0.829       0
# 30          0.740       1
# 53          0.649       1
# 9           0.776       1
# ..            ...     ...
# 109         0.699       0
# 2           0.824       1
# 47          0.585       1
# 132         0.315       0
# 168         0.663       0
#
# [200 rows x 14 columns]

# %% [markdown]
# ### Knowing the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            200 non-null    object
#  1   name          200 non-null    object
#  2   duration      200 non-null    float64
#  3   energy        200 non-null    float64
#  4   key           200 non-null    int64
#  5   loudness      200 non-null    float64
#  6   mode          200 non-null    int64
#  7   speechiness   200 non-null    float64
#  8   acousticness  200 non-null    float64
#  9   liveness      200 non-null    float64
#  10  valence       200 non-null    float64
#  11  tempo         200 non-null    float64
#  12  danceability  200 non-null    float64
#  13  Status        200 non-null    int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 22.0+ KB

# %% [markdown]
# ### Checking Null values

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# duration        0
# energy          0
# key             0
# loudness        0
# mode            0
# speechiness     0
# acousticness    0
# liveness        0
# valence         0
# tempo           0
# danceability    0
# Status          0
# dtype: int64

# %% [markdown]
# * No null value in any column

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# * Summary of Numerical variables (By default)

# %%
des_stat=df.describe()
print(des_stat)
# Out:
#          duration      energy         key    loudness        mode  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    13.510200    0.526752    4.910000   -8.434520    0.635000
# std     14.060892    0.207745    3.631506    4.059083    0.482638
# min      1.520000    0.010600    0.000000  -20.896000    0.000000
# 25%      3.512500    0.383000    1.000000  -10.508750    0.000000
# 50%      7.565000    0.546500    5.000000   -7.306000    1.000000
# 75%     18.935000    0.686000    8.000000   -5.592750    1.000000
# max     58.020000    0.939000   11.000000   -1.770000    1.000000
#
#        speechiness  acousticness    liveness     valence       tempo  \
# count   200.000000    200.000000  200.000000  200.000000  200.000000
# mean      0.157334      0.357907    0.170185    0.472193  119.983225
# std       0.166150      0.322425    0.120957    0.219025   31.432829
# min       0.027200      0.000025    0.034400    0.035900   69.180000
# 25%       0.041925      0.045850    0.095600    0.322250   94.976250
# 50%       0.075250      0.289500    0.119000    0.446000  115.681000
# 75%       0.247000      0.647250    0.214000    0.611750  142.178000
# max       0.872000      0.991000    0.790000    0.969000  207.198000
#
#        danceability      Status
# count    200.000000  200.000000
# mean       0.640400    0.500000
# std        0.151442    0.501255
# min        0.187000    0.000000
# 25%        0.545250    0.000000
# 50%        0.664000    0.500000
# 75%        0.753250    1.000000
# max        0.955000    1.000000

# %% [markdown]
# ### Dropping unwanted columns

# %%
col=['id','name']
df=df.drop(columns=col,axis=1)

# %%
df
# Out:
#      duration  energy  key  loudness  mode  speechiness  acousticness  \
# 0        3.33  0.7300    1    -5.934     1       0.0598       0.00146
# 1        3.90  0.6520    1    -3.183     0       0.0802       0.58100
# 2        3.49  0.5880    6    -6.400     0       0.0924       0.69200
# 3        3.04  0.4050    1    -5.679     1       0.0319       0.75100
# 4        3.64  0.5200    5    -6.136     0       0.0712       0.12400
# ..        ...     ...  ...       ...   ...          ...           ...
# 195     11.60  0.0422   11   -17.662     0       0.1640       0.75300
# 196     49.75  0.5920    6   -11.658     0       0.0359       0.00758
# 197     12.40  0.4030    0   -16.342     1       0.0881       0.98000
# 198     55.26  0.7140    0    -4.629     1       0.0370       0.00153
# 199     48.43  0.6570    7    -4.638     0       0.0316       0.02690
#
#      liveness  valence    tempo  danceability  Status
# 0      0.0897    0.334  171.005         0.514       1
# 1      0.0931    0.931   95.977         0.825       1
# 2      0.1490    0.513   98.027         0.824       1
# 3      0.1050    0.446  109.891         0.501       1
# 4      0.1310    0.129  159.801         0.585       1
# ..        ...      ...      ...           ...     ...
# 195    0.0790    0.547  109.021         0.717       0
# 196    0.5940    0.350  119.948         0.531       0
# 197    0.1560    0.297   80.011         0.187       0
# 198    0.1090    0.326  168.394         0.361       0
# 199    0.0899    0.353  142.532         0.376       0
#
# [200 rows x 12 columns]

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Finding Correlation

# %%
cor_mat=df.corr()
cor_mat
# Out:
#               duration    energy       key  loudness      mode  speechiness  \
# duration      1.000000 -0.261893 -0.086580 -0.262316  0.064418     0.120941
# energy       -0.261893  1.000000 -0.044435  0.828784  0.022386    -0.280870
# key          -0.086580 -0.044435  1.000000 -0.040615 -0.228133    -0.054839
# loudness     -0.262316  0.828784 -0.040615  1.000000  0.108399    -0.432550
# mode          0.064418  0.022386 -0.228133  0.108399  1.000000    -0.122849
# speechiness   0.120941 -0.280870 -0.054839 -0.432550 -0.122849     1.000000
# acousticness  0.279345 -0.688929  0.058200 -0.557682  0.048407     0.071210
# liveness     -0.096820  0.071673  0.027816  0.017980 -0.080311    -0.041771
# valence      -0.220804  0.175988  0.052042  0.075182 -0.038385     0.032153
# tempo         0.061002  0.166744 -0.018444  0.095234  0.039828    -0.095778
# danceability -0.219340 -0.007302  0.013479 -0.013127 -0.164439     0.298859
# Status       -0.704058  0.476527  0.118705  0.557731  0.031157    -0.367371
#
#               acousticness  liveness   valence     tempo  danceability  \
# duration          0.279345 -0.096820 -0.220804  0.061002     -0.219340
# energy           -0.688929  0.071673  0.175988  0.166744     -0.007302
# key               0.058200  0.027816  0.052042 -0.018444      0.013479
# loudness         -0.557682  0.017980  0.075182  0.095234     -0.013127
# mode              0.048407 -0.080311 -0.038385  0.039828     -0.164439
# speechiness       0.071210 -0.041771  0.032153 -0.095778      0.298859
# acousticness      1.000000 -0.064853 -0.091552 -0.170725     -0.256878
# liveness         -0.064853  1.000000  0.019447 -0.092927     -0.084961
# valence          -0.091552  0.019447  1.000000  0.033447      0.239380
# tempo            -0.170725 -0.092927  0.033447  1.000000     -0.099607
# danceability     -0.256878 -0.084961  0.239380 -0.099607      1.000000
# Status           -0.301453 -0.037322  0.136575  0.040527      0.061100
#
#                 Status
# duration     -0.704058
# energy        0.476527
# key           0.118705
# loudness      0.557731
# mode          0.031157
# speechiness  -0.367371
# acousticness -0.301453
# liveness     -0.037322
# valence       0.136575
# tempo         0.040527
# danceability  0.061100
# Status        1.000000

# %%
sns.heatmap(cor_mat,cmap='YlGnBu',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['loudness'],kde=True,bins=8)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='loudness', ylabel='Density'>

# %%
sns.boxplot('Status','energy',data=df,showmeans=True,meanprops={'marker':'*','markerfacecolor':'white','markeredgecolor':'black','markersize':'10'}) #corr=0.48
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='energy'>

# %%
sns.boxplot('Status','duration',data=df,showmeans=True,meanprops={'marker':'*','markerfacecolor':'white','markeredgecolor':'black','markersize':'10'}) #corr=-0.7
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='duration'>

# %%
sns.boxplot('Status','loudness',data=df,showmeans=True,meanprops={'marker':'*','markerfacecolor':'white','markeredgecolor':'black','markersize':'10'}) #corr=0.56
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='loudness'>

# %%
sns.distplot(df['duration'],bins=10)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
plt.hist(df['duration'],color='purple',edgecolor='white',bins=10)
plt.title('Distribution of Duration')
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(df['mode'])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mode', ylabel='count'>

# %%
Index=[]
for i in range(0,200):
    Index.append(i)
#Index

# %%
df['index']=Index
df
# Out:
#      duration  energy  key  loudness  mode  speechiness  acousticness  \
# 0        3.33  0.7300    1    -5.934     1       0.0598       0.00146
# 1        3.90  0.6520    1    -3.183     0       0.0802       0.58100
# 2        3.49  0.5880    6    -6.400     0       0.0924       0.69200
# 3        3.04  0.4050    1    -5.679     1       0.0319       0.75100
# 4        3.64  0.5200    5    -6.136     0       0.0712       0.12400
# ..        ...     ...  ...       ...   ...          ...           ...
# 195     11.60  0.0422   11   -17.662     0       0.1640       0.75300
# 196     49.75  0.5920    6   -11.658     0       0.0359       0.00758
# 197     12.40  0.4030    0   -16.342     1       0.0881       0.98000
# 198     55.26  0.7140    0    -4.629     1       0.0370       0.00153
# 199     48.43  0.6570    7    -4.638     0       0.0316       0.02690
#
#      liveness  valence    tempo  danceability  Status  index
# 0      0.0897    0.334  171.005         0.514       1      0
# 1      0.0931    0.931   95.977         0.825       1      1
# 2      0.1490    0.513   98.027         0.824       1      2
# 3      0.1050    0.446  109.891         0.501       1      3
# 4      0.1310    0.129  159.801         0.585       1      4
# ..        ...      ...      ...           ...     ...    ...
# 195    0.0790    0.547  109.021         0.717       0    195
# 196    0.5940    0.350  119.948         0.531       0    196
# 197    0.1560    0.297   80.011         0.187       0    197
# 198    0.1090    0.326  168.394         0.361       0    198
# 199    0.0899    0.353  142.532         0.376       0    199
#
# [200 rows x 13 columns]

# %%
sns.regplot(y=df['duration'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='duration'>

# %% [markdown]
# * Duration is strongly Significant

# %%
sns.regplot(y=df['energy'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='energy'>

# %% [markdown]
# * Energy is Significant

# %%
sns.regplot(y=df['key'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='key'>

# %% [markdown]
# * Key is not Significant

# %%
sns.regplot(y=df['loudness'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='loudness'>

# %% [markdown]
# * Loudness is Significant

# %%
sns.regplot(y=df['mode'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='mode'>

# %% [markdown]
# * Mode is Not Significant

# %%
sns.regplot(y=df['speechiness'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='speechiness'>

# %% [markdown]
# * Weak Significant

# %%
sns.regplot(y=df['acousticness'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='acousticness'>

# %% [markdown]
# * Weakly Significant

# %%
sns.regplot(y=df['liveness'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='liveness'>

# %% [markdown]
# * Not Significant

# %%
sns.regplot(y=df['valence'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='valence'>

# %% [markdown]
# * Not Significant

# %%
sns.regplot(y=df['tempo'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='tempo'>

# %% [markdown]
# * Not Significant

# %%
sns.regplot(y=df['danceability'],x=df['index'],fit_reg=True)
# Out:
# <AxesSubplot:xlabel='index', ylabel='danceability'>

# %% [markdown]
# * Not Significant

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * dependent variable = Status
# * independent variables - duration, energy, loudness, speechiness, acousticness

# %%
all_var=list(df.columns)

# %%
print(all_var)
# Out:
# ['duration', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo', 'danceability', 'Status', 'index']

# %% [markdown]
# ### Independent Variables X

# %%
indp_var=list(set(all_var)-set(['key','mode','liveness','valence','tempo','danceability','Status','index']))

# %%
indp_var
# Out:
# ['duration', 'acousticness', 'loudness', 'energy', 'speechiness']

# %%
# Extracting independent variable values

# %%
x=df[indp_var].values

# %%
x.shape
# Out:
# (200, 5)

# %% [markdown]
# ### Dependent Variable Y

# %%
y = df['Status'].values

# %%
y.shape
# Out:
# (200,)

# %% [markdown]
# ### Splitting the data

# %% [markdown]
# ##### Import the libraries

# %%
from sklearn.model_selection import train_test_split # to partition the data
from sklearn.linear_model import LogisticRegression # For logistic regression
from sklearn.metrics import accuracy_score, confusion_matrix # importing performance matrix for accuracy score and confusion matix

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=0)
# test data = 20% for both x and y
# random_state=0 means output of data will not change each time if the command is run several times

# %%
print(train_x.shape)
# 80% of x
# Out:
# (160, 5)

# %%
test_x.shape
# Out:
# (40, 5)

# %%
train_y.shape
# Out:
# (160,)

# %%
test_y.shape
# Out:
# (40,)

# %% [markdown]
# ### Fit the Logistic Regression Model

# %%
logistic=LogisticRegression() # Making the model easy to call

# %%
logistic.fit(train_x,train_y) # train_x is independent variable, train_y is dependent variable
# Out:
# LogisticRegression()

# %% [markdown]
# ### Coefficient and Intercept

# %%
logistic.coef_
# Out:
# array([[-1.59299198e+00,  5.36937445e-02,  3.21727705e-01,
#         -1.59412994e-04, -1.56822749e-02]])

# %%
logistic.intercept_
# Out:
# array([14.79139248])

# %% [markdown]
# ### Prediction on Test data

# %% [markdown]
# * Put test_x in prediction function so we will get predicted values of y
# * Then these values can be compared with the actual test_y data set

# %%
prediction=logistic.predict(test_x) # prediction = predicted values of y

# %%
prediction.shape
# Out:
# (40,)

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# * Used to check the accuracy of predicted values
# * Usually return the correct and incorrect predictions
# * Diagonal values are correctly classified values
# * Off diagonal values are incorrectly classified values

# %%
conf_mat=confusion_matrix(test_y,prediction)
print(conf_mat)
# Out:
# [[22  0]
#  [ 0 18]]

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=conf_mat,display_labels=[False,True])
cm_display.plot()
plt.show()

# %% [markdown]
# ###### Accuracy Score

# %%
acc=accuracy_score(test_y,prediction)

# %%
acc
# Out:
# 1.0

# %%
lg_diff = pd.DataFrame({'Actual value': test_y, 'Predicted value': prediction})
lg_diff.head()
# Out:
#    Actual value  Predicted value
# 0             1                1
# 1             0                0
# 2             0                0
# 3             1                1
# 4             0                0

# %% [markdown]
# ### Model Evolution¶

# %%
# Mean Absolute Error (MAE)
print(metrics.mean_absolute_error(test_y,prediction))
# Out:
# 0.0

# %%
# Mean Squared Error (MSE)
print(metrics.mean_squared_error(test_y,prediction))
# Out:
# 0.0

# %%
# Root Mean Squared Error (RMSE)
print(np.sqrt(metrics.mean_squared_error(test_y,prediction)))
# Out:
# 0.0

# %% [markdown]
# ##### Import Library

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(test_y,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      1.00      1.00        18
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %% [markdown]
# ### ROC Curve (The receiver operating characteristic (ROC))

# %% [markdown]
# * The dotted line represents the ROC curve of a purely random classifier
# * A good classifier stays as far away from that line as possible (toward the top-left corner).

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(test_y, logistic.predict(test_x))
fpr, tpr, thresholds = roc_curve(test_y, logistic.predict_proba(test_x)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# #### Importing few libraries

# %%
from sklearn import metrics # import metrics library

# %%
# Dataset
df2 #shuffle
# Out:
#                          id                   name  duration  energy  key  \
# 192  4R9OIaic0WuA40tMV7ZMw3  The Itsy Bitsy Spider     11.82  0.0926   11
# 190  7gzBdhUHisyTFLvOdTiIYh          London Bridge      8.08  0.0332    2
# 30   3ee8Jmje8o58CHK66QrVC2                   Sad!      2.78  0.6130    8
# 53   0lYBSQXN6rCTvUZvg9S0lU        Let Me Love You      3.43  0.7160    8
# 9    0pqnGHJpmpxLKifKRmU6WP               Believer      3.41  0.7800   10
# ..                      ...                    ...       ...     ...  ...
# 109  1HlVLS4ee3GiYocfcg8TgB                   irie     43.83  0.2090    6
# 2    2XU0oxnq2qxCpomAAuJY8K           Dance Monkey      3.49  0.5880    6
# 47   7fBv7CLKzipRk6EC6TWHOB              The Hills      4.04  0.5640    0
# 132  1Q9oighVictEedPJRcY2Ii         How Many Whips     10.18  0.5900    5
# 168  3tjfT7tho5CoHchikYOaa0     Summer Burn (Live)     36.38  0.3830    4
#
#      loudness  mode  speechiness  acousticness  liveness  valence    tempo  \
# 192   -17.108     0       0.1610        0.9760    0.1620    0.523   69.180
# 190   -20.896     1       0.1190        0.9910    0.3820    0.884  108.641
# 30     -4.880     1       0.1450        0.2580    0.1230    0.473   75.023
# 53     -5.371     1       0.0349        0.0863    0.1350    0.163   99.988
# 9      -4.374     0       0.1280        0.0622    0.0810    0.666  124.949
# ..        ...   ...          ...           ...       ...      ...      ...
# 109   -14.410     1       0.6200        0.3670    0.0632    0.298   89.102
# 2      -6.400     0       0.0924        0.6920    0.1490    0.513   98.027
# 47     -7.063     0       0.0515        0.0671    0.1350    0.137  113.003
# 132    -6.843     1       0.0607        0.1480    0.5170    0.382  134.752
# 168    -9.616     1       0.0284        0.8370    0.2060    0.288  128.123
#
#      danceability  Status
# 192         0.695       0
# 190         0.829       0
# 30          0.740       1
# 53          0.649       1
# 9           0.776       1
# ..            ...     ...
# 109         0.699       0
# 2           0.824       1
# 47          0.585       1
# 132         0.315       0
# 168         0.663       0
#
# [200 rows x 14 columns]

# %%
sns.regplot(df['energy'],df['loudness'],color='purple') # corr = 0.83
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='energy', ylabel='loudness'>

# %% [markdown]
# * There is a strong correlation between loudness and energy
# * We can predict energy by measuring loudness in a song
# * If loudness is high, energy will be high, then the song should be hit
# * This can be done using simple linear regression

# %% [markdown]
# * Dependent variable - energy
# * Independent variable - loudness

# %%
sns.distplot(df['energy'],bins=5)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='energy', ylabel='Density'>

# %%
sns.distplot(df['loudness'],bins=5)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='loudness', ylabel='Density'>

# %% [markdown]
# ### Extracting Values of dependent y and independent variable x

# %%
y1=pd.array(df['energy']) #dependent
y1
# Out:
# <PandasArray>
# [  0.73,  0.652,  0.588,  0.405,   0.52,  0.479,  0.625,  0.524,   0.31,
#    0.78,
#  ...
#  0.0332, 0.0204, 0.0926, 0.0433, 0.0774, 0.0422,  0.592,  0.403,  0.714,
#   0.657]
# Length: 200, dtype: float64

# %%
x1=pd.array(df['loudness']).reshape(-1,1) #independent
x1
# Out:
# <PandasArray>
# [
# [-5.934],
# [-3.183],
# [-6.4],
# [-5.679],
# [-6.136],
# [-5.574],
# [-5.609],
# [-5.599],
# [-10.164],
# [-4.374],
# [-6.049],
# [-6.818],
# [-6.9],
# [-7.398],
# [-7.015],
# [-10.965],
# [-6.061],
# [-7.23],
# [-12.205],
# [-10.109],
# [-4.209],
# [-9.211],
# [-10.48],
# [-9.961],
# [-6.769],
# [-2.81],
# [-6.362],
# [-5.338],
# [-9.828],
# [-3.497],
# [-4.88],
# [-5.303],
# [-7.064],
# [-5.175],
# [-10.732],
# [-3.37],
# [-9.144],
# [-4.333],
# [-5.677],
# [-6.366],
# [-4.972],
# [-6.021],
# [-5.697],
# [-6.694],
# [-6.009],
# [-6.638],
# [-7.346],
# [-7.063],
# [-3.714],
# [-6.351],
# [-5.044],
# [-7.811],
# [-3.24],
# [-5.371],
# [-8.81],
# [-3.081],
# [-4.078],
# [-5.472],
# [-5.804],
# [-6.444],
# [-4.183],
# [-5.085],
# [-2.827],
# [-7.409],
# [-4.565],
# [-6.306],
# [-3.015],
# [-5.23],
# [-7.223],
# [-8.237],
# [-3.787],
# [-6.645],
# [-7.539],
# [-5.634],
# [-5.041],
# [-10.059],
# [-6.725],
# [-6.595],
# [-7.596],
# [-5.043],
# [-3.724],
# [-4.353],
# [-5.723],
# [-4.097],
# [-8.492],
# [-4.961],
# [-6.687],
# [-3.237],
# [-4.063],
# [-6.684],
# [-5.608],
# [-4.556],
# [-9.222],
# [-6.726],
# [-7.621],
# [-5.829],
# [-7.227],
# [-4.209],
# [-4.787],
# [-5.51],
# [-8.203],
# [-11.392],
# [-11.799],
# [-10.818],
# [-15.624],
# [-15.728],
# [-11.843],
# [-16.269],
# [-14.677],
# [-14.41],
# [-16.745],
# [-15.798],
# [-11.542],
# [-9.722],
# [-10.75],
# [-7.322],
# [-12.741],
# [-12.669],
# [-12.536],
# [-10.118],
# [-11.013],
# [-9.17],
# [-7.272],
# [-6.502],
# [-6.143],
# [-4.418],
# [-6.497],
# [-8.196],
# [-9.541],
# [-10.595],
# [-8.357],
# [-11.452],
# [-6.843],
# [-5.024],
# [-6.59],
# [-7.29],
# [-10.84],
# [-7.71],
# [-7.057],
# [-8.568],
# [-10.377],
# [-10.767],
# [-14.128],
# [-14.548],
# [-12.92],
# [-13.107],
# [-7.699],
# [-11.188],
# [-9.223],
# [-13.11],
# [-9.829],
# [-7.44],
# [-14.357],
# [-6.858],
# [-9.483],
# [-9.011],
# [-10.325],
# [-19.078],
# [-8.674],
# [-12.776],
# [-5.322],
# [-9.937],
# [-8.731],
# [-9.42],
# [-11.328],
# [-12.733],
# [-10.155],
# [-12.254],
# [-9.616],
# [-12.634],
# [-10.091],
# [-12.815],
# [-1.77],
# [-3.647],
# [-1.814],
# [-4.445],
# [-3.579],
# [-4.558],
# [-7.895],
# [-8.473],
# [-9.115],
# [-15.045],
# [-9.078],
# [-8.004],
# [-6.028],
# [-9.776],
# [-6.136],
# [-20.771],
# [-18.348],
# [-19.366],
# [-20.896],
# [-20.748],
# [-17.108],
# [-18.886],
# [-19.14],
# [-17.662],
# [-11.658],
# [-16.342],
# [-4.629],
# [-4.638]
# ]
# Shape: (200, 1), dtype: float64

# %%
train_x1,test_x1,train_y1,test_y1=train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
print(train_x1.shape)
print(test_x1.shape)
print(train_y1.shape)
print(test_y1.shape)
# Out:
# (160, 1)
# (40, 1)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(train_x1,train_y1)
# Out:
# LinearRegression()

# %%
print('Intercept :',lr.intercept_)
# Out:
# Intercept : 0.8924245120919323

# %%
print('Coefficient :',lr.coef_)
# Out:
# Coefficient : [0.04304969]

# %% [markdown]
# ##### Regression Equation

# %% [markdown]
# energy = 0.8924 + (0.0430)loudness

# %% [markdown]
# ### Accuracy Score

# %%
r_sq=lr.score(x1,y1)
print(r_sq)
# Out:
# 0.6865766431463373

# %% [markdown]
# * 68.66% is the accuaracy score for this model

# %%
prediction1=lr.predict(test_x1)

# %%
prediction1.shape
# Out:
# (40,)

# %% [markdown]
# * Actual Values and Predicted Values

# %%
lr_diff = pd.DataFrame({'Actual value': test_y1, 'Predicted value': prediction1})
lr_diff.head()
# Out:
#    Actual value  Predicted value
# 0         0.185         0.367003
# 1         0.332         0.458010
# 2         0.235         0.192049
# 3         0.797         0.686346
# 4         0.565         0.696204

# %% [markdown]
# ### Model Evolution

# %% [markdown]
# ##### There are three primary metrics used to evaluate linear models.

# %% [markdown]
# * MAE: The easiest to understand. Represents average error
# * MSE: Similar to MAE but noise is exaggerated and larger errors are “punished”. It is harder to interpret than MAE as it’s not in base units, however, it is generally more popular.
# * RMSE: Most popular metric, similar to MSE, however, the result is square rooted to make it more interpretable as it’s in base units. It is recommended that RMSE be used as the primary metric to interpret your model.

# %%
# Mean Absolute Error (MAE)
print(metrics.mean_absolute_error(test_y1,prediction1))
# Out:
# 0.09914582250835405

# %%
# Mean Squared Error (MSE)
print(metrics.mean_squared_error(test_y1,prediction1))
# Out:
# 0.013915640588880368

# %%
# Root Mean Squared Error (RMSE)
print(np.sqrt(metrics.mean_squared_error(test_y1,prediction1)))
# Out:
# 0.11796457344847379

# %% [markdown]
# * Since RMSE value is low, which indicates that the model is good fit and it can accurately give the predictions

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# * Dependent Variable - acousticness
# * Independent Variable - energy , loudness

# %%
df # dataset
# Out:
#      duration  energy  key  loudness  mode  speechiness  acousticness  \
# 0        3.33  0.7300    1    -5.934     1       0.0598       0.00146
# 1        3.90  0.6520    1    -3.183     0       0.0802       0.58100
# 2        3.49  0.5880    6    -6.400     0       0.0924       0.69200
# 3        3.04  0.4050    1    -5.679     1       0.0319       0.75100
# 4        3.64  0.5200    5    -6.136     0       0.0712       0.12400
# ..        ...     ...  ...       ...   ...          ...           ...
# 195     11.60  0.0422   11   -17.662     0       0.1640       0.75300
# 196     49.75  0.5920    6   -11.658     0       0.0359       0.00758
# 197     12.40  0.4030    0   -16.342     1       0.0881       0.98000
# 198     55.26  0.7140    0    -4.629     1       0.0370       0.00153
# 199     48.43  0.6570    7    -4.638     0       0.0316       0.02690
#
#      liveness  valence    tempo  danceability  Status  index
# 0      0.0897    0.334  171.005         0.514       1      0
# 1      0.0931    0.931   95.977         0.825       1      1
# 2      0.1490    0.513   98.027         0.824       1      2
# 3      0.1050    0.446  109.891         0.501       1      3
# 4      0.1310    0.129  159.801         0.585       1      4
# ..        ...      ...      ...           ...     ...    ...
# 195    0.0790    0.547  109.021         0.717       0    195
# 196    0.5940    0.350  119.948         0.531       0    196
# 197    0.1560    0.297   80.011         0.187       0    197
# 198    0.1090    0.326  168.394         0.361       0    198
# 199    0.0899    0.353  142.532         0.376       0    199
#
# [200 rows x 13 columns]

# %% [markdown]
# ##### Extracting the dependent and independent variable

# %%
x2=df[['energy','loudness']] #independent variables

# %%
y2=df['acousticness'] # dependent variable

# %%
train_x2,test_x2,train_y2,test_y2=train_test_split(x2,y2,test_size=0.2,random_state=0)

# %%
print(train_x2.shape)
print(test_x2.shape)
print(train_y2.shape)
print(test_y2.shape)
# Out:
# (160, 2)
# (40, 2)
# (160,)
# (40,)

# %%
mlr=LinearRegression()

# %%
mlr.fit(train_x2,train_y2)
# Out:
# LinearRegression()

# %%
print('Intercept :',mlr.intercept_)
# Out:
# Intercept : 1.0687363809081976

# %%
print('Coefficients :',mlr.coef_)
# Out:
# Coefficients : [-1.19310894  0.00833757]

# %% [markdown]
# ##### Regression Equation

# %% [markdown]
# acousticness = 1.0687 + (-1.1931)*energy + (0.0083)*loudness

# %% [markdown]
# ### Accuracy Score

# %%
r_sq2=mlr.score(x2,y2)
print(r_sq2)
# Out:
# 0.4725121290253699

# %% [markdown]
# * 47.25% is the accuracy score for this model

# %%
prediction2=mlr.predict(test_x2)

# %%
prediction2.shape
# Out:
# (40,)

# %%
mlr_diff = pd.DataFrame({'Actual value':test_y2, 'Predicted value': prediction2})
mlr_diff.head()
# Out:
#      Actual value  Predicted value
# 18         0.8760         0.746251
# 170        0.8410         0.588490
# 107        0.7480         0.652712
# 98         0.1980         0.077917
# 177        0.0448         0.356627

# %% [markdown]
# ### Model Evolution

# %%
# Mean Absolute Error (MAE)
print(metrics.mean_absolute_error(test_y2,prediction2))
# Out:
# 0.19619863082831687

# %%
# Mean Squared Error (MSE)
print(metrics.mean_squared_error(test_y2,prediction2))
# Out:
# 0.058950825684263984

# %%
# Root Mean Squared Error (RMSE)
print(np.sqrt(metrics.mean_squared_error(test_y2,prediction2)))
# Out:
# 0.24279791120243185
